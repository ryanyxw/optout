# %%
# !pip install nltk
import json
import gzip
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')

# %%
data = list(open("../../johnny/optout/outputs/00_0-1000.jsonl", "rt"))

# %%
print(len(data))
# Out:
# 1000

# %%
data[0]
# Out:
# '{"index": 0, "meta": {"pile_set_name": "Pile-CC"}, "tokens": ["It", "\\u0120is", "\\u0120done", ",", "\\u0120and", "\\u0120submitted", ".", "\\u0120You", "\\u0120can", "\\u0120play", "\\u0120\\u00e2\\u0122", "\\u013e", "Surv", "ival", "\\u0120of", "\\u0120the", "\\u0120T", "ast", "iest", "\\u00e2\\u0122", "\\u013f", "\\u0120on", "\\u0120Android", ",", "\\u0120and", "\\u0120on", "\\u0120the", "\\u0120web", ".", "\\u0120Playing", "\\u0120on", "\\u0120the", "\\u0120web", "\\u0120works", ",", "\\u0120but", "\\u0120you", "\\u0120have", "\\u0120to", "\\u0120simulate", "\\u0120multi", "-", "touch", "\\u0120for", "\\u0120table", "\\u0120moving", "\\u0120and", "\\u0120that", "\\u0120can", "\\u0120be", "\\u0120a", "\\u0120bit", "\\u0120confusing", ".", "\\u010a", "\\u010a", "There", "\\u00e2\\u0122", "\\u013b", "s", "\\u0120a", "\\u0120lot", "\\u0120I", "\\u00e2\\u0122", "\\u013b", "d", "\\u0120like", "\\u0120to", "\\u0120talk", "\\u0120about", ".", "\\u0120I", "\\u00e2\\u0122", "\\u013b", "l
# ...
