# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Oxford_Comma_Data/output:val_oxford.csv', header=None, names=['idx', 'sentence', 'contains', 'probability'])
df.probability = df.probability.astype(float)
df
# Out:
#          idx  \
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 12343  12343
# 12344  12344
# 12345  12345
# 12346  12346
# 12347  12347
#
#                                                                                                                                                                                             sentence  \
# 0                                                                                                  La Vanguardia writes: "Major forces supporting independence should look back, confess to mistakes
# 1                                                                                                                                   Mr Rajoy then sacked the Catalan government, imposed direct rule
# 2                                                                                                      It is the first stablecoins to be pegged to different fiat currencies like USD, EUR, GBP, HKD
# ...

# %%
df.groupby('contains').mean()
# Out:
# /tmp/ipykernel_86949/2007284738.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('contains').mean()
#                   idx  probability
# contains
# False     6059.502149     0.218960
# True      6376.825293     0.483334

# %%
sns.histplot(data=df, log_scale=True, x='probability', hue='contains', stat='proportion')
# Out:
# <Axes: xlabel='probability', ylabel='Proportion'>

# %%
pd.options.display.max_colwidth = 1000
df[df.probability > 0.9]
# Out:
#          idx  \
# 82        82
# 177      177
# 209      209
# 217      217
# 426      426
# ...      ...
# 13012  13012
# 13013  13013
# 13014  13014
# 13016  13016
# 13028  13028
#
#                                                                                                                            sentence  \
# 82                 A court abuses its discretion if its    decision to admit such evidence is manifestly arbitrary,    unreasonable
# 177    ](zjv0241840640003){#F3}  Northern blot analyses showed that HBV RNA was only detected in serum samples from patients 17, 21
# 209                                                     Pellets were suspended in TNE buffer (10 mM Tris-Cl \[pH 7.5\], 100 mM NaCl
# 217                                Subsequently, the membrane was washed twice with washing buffer (100 mM maleic acid, 150 mM NaCl
# 426                                                            The collection embraces works from such masters as Constable, Turner
# ...
